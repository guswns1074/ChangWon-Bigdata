# %%
import pandas as pd
final = pd.read_excel('보간법_scaled.xlsx')
bus_num = pd.read_excel('버스번호.xlsx')

# %%
final
# Out:
#       Unnamed: 0    no      id       station   Mon   Tue   Wed   Thu   Fri  \
# 0              0     1  103118       힐스테이트4차   360   426   397   391   445
# 1              1     2  103115       힐스테이트3차    45    42    63    66    32
# 2              2     3  103103       힐스테이트1차   282   326   301   329   308
# 3              3     4  119303       흥한웰가아파트  1735  1882  1674  1644  1727
# 4              4     5  103602     휴먼시아2단지입구    95   103    91    92    92
# 5              5     6  103601       휴먼시아2단지    71    87    87   102    89
# 6              6     7  109501       휴먼시아1단지   164   144   141   152   140
# 7              7     8  104713        휴먼빌2단지   266   267   262   274   294
# 8              8     9  104721      휴먼빌3차아파트    36    30    42    35    40
# 9              9    10  104714        휴먼빌1단지    25    30    32    19    31
# 10            10    11  201211         효성중공업    37    38    37    35    33
# ...

# %%
bus_num = bus_num.drop_duplicates('station')

# %%
final2 = pd.merge(final,bus_num,on='station')

# %%
final2['버스번호'][0] = final2['버스번호'][1]
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df3 = final2[['station','버스번호']]

# %%
df4 = pd.read_excel('버스배차.xlsx')

# %%
df4
# Out:
#      버스번호                                            첫차막차  \
# 0       1  평일05:40 ~23:00 토요일05:40 ~23:00 공휴일05:40 ~23:00
# 1       2  평일06:35 ~21:50 토요일06:35 ~21:50 공휴일06:35 ~21:50
# 2       3  평일08:05 ~17:55 토요일08:05 ~17:55 공휴일08:05 ~17:55
# 3       7  평일06:20 ~23:10 토요일06:12 ~23:10 공휴일06:12 ~23:10
# 4       8  평일06:00 ~23:00 토요일06:00 ~23:00 공휴일06:00 ~23:00
# 5      10  평일06:05 ~22:15 토요일06:05 ~22:15 공휴일06:05 ~22:15
# 6      11  평일07:10 ~22:25 토요일07:10 ~22:25 공휴일07:10 ~22:25
# 7      12  평일05:20 ~21:40 토요일05:20 ~21:40 공휴일05:20 ~21:40
# 8      13  평일05:45 ~22:10 토요일05:45 ~22:10 공휴일05:45 ~22:10
# 9      14  평일05:25 ~21:50 토요일05:25 ~21:50 공휴일05:25 ~21:50
# 10     15  평일05:20 ~20:35 토요일05:20 ~20:35 공휴일05:20 ~20:35
# 11     17  평일05:00 ~22:48 토요일05:00 ~22:48 공휴일05:00 ~22:48
# 12     19  평일06:00 ~22:00 토요일06:00 ~22:00 공휴일06:00 ~22:00
# 13     20  평일05:50 ~22:55 토요일05:50 ~22:55 공휴일05:50 ~22:55
# 14     21  평일06:10 ~22:00 토요일06:10 ~22:00 공휴일06:10 ~22:00
# ...

# %%
df3['버스번호'] = df3['버스번호'].str.replace('\n',' ')
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for i in range(0,len(df3)):
    df3['버스번호'][i] = df3['버스번호'][i].split(' ')
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3
# Out:
#            station                                               버스번호
# 0          힐스테이트4차                                  [17, 19, 27, 530]
# 1          힐스테이트3차                                  [17, 19, 27, 530]
# 2          힐스테이트1차                      [12, 17, 19, 22, 27, 29, 530]
# 3          흥한웰가아파트  [10, 11, 12, 13, 14, 15, 17, 19, 20, 21, 22, 2...
# 4        휴먼시아2단지입구                                         [220, 221]
# 5          휴먼시아2단지                                         [220, 221]
# 6          휴먼시아1단지                                         [220, 221]
# 7           휴먼빌2단지                      [12, 17, 19, 22, 27, 29, 530]
# 8         휴먼빌3차아파트                           [12, 17, 19, 22, 27, 29]
# 9           휴먼빌1단지                      [12, 17, 19, 22, 27, 29, 530]
# 10           효성중공업      [107, 150, 501, 502, 503, 503, 504, 504, 751]
# 11          회원초등학교                                         [105, 707]
# ...

# %%
d=[]
for i in range(0,len(df4)):
    c=[]
    for j in range(0,len(df3)):
        if df4['버스번호'][i] in df3['버스번호'][j]:
            c.append(df3['station'][j])
    d.append(c)

# %%
for j in range(0,len(df3))
        for k in range(0,len(df3['버스번호'][j][k]))
        if df4['버스번호'][0] in df3['버스번호'][j]:
            c.append(df3['station'][j])
len(list(set(c)))
# Out:
#   File "<ipython-input-171-38f2534bb0ac>", line 1
#     for j in range(0,len(df3))
#                               ^
# SyntaxError: invalid syntax

# %%
df4['station_list']= d

# %%
# Out:
#       Unnamed: 0    no      id       station   Mon   Tue   Wed   Thu   Fri  \
# 0              0     1  103118       힐스테이트4차   360   426   397   391   445
# 1              1     2  103115       힐스테이트3차    45    42    63    66    32
# 2              2     3  103103       힐스테이트1차   282   326   301   329   308
# 3              3     4  119303       흥한웰가아파트  1735  1882  1674  1644  1727
# 4              4     5  103602     휴먼시아2단지입구    95   103    91    92    92
# 5              5     6  103601       휴먼시아2단지    71    87    87   102    89
# 6              6     7  109501       휴먼시아1단지   164   144   141   152   140
# 7              7     8  104713        휴먼빌2단지   266   267   262   274   294
# 8              8     9  104721      휴먼빌3차아파트    36    30    42    35    40
# 9              9    10  104714        휴먼빌1단지    25    30    32    19    31
# 10            10    11  201211         효성중공업    37    38    37    35    33
# ...

# %%
final = pd.read_excel('정류장점수.xlsx')

# %%
df5 = final[['station','total_num']]

# %%
df5
# Out:
#            station  total_num
# 0          힐스테이트4차  -0.192106
# 1          힐스테이트3차  -0.303008
# 2          힐스테이트1차   0.206110
# 3          흥한웰가아파트   0.883303
# 4        휴먼시아2단지입구  -1.599152
# 5          휴먼시아2단지  -1.604391
# 6          휴먼시아1단지  -1.582560
# 7           휴먼빌2단지  -0.207391
# 8         휴먼빌3차아파트  -0.283789
# 9           휴먼빌1단지  -0.281567
# 10           효성중공업   5.848735
# 11          회원초등학교  -0.043128
# 12            회원신협   0.081559
# 13            회원1동   0.649322
# 14         회성동주민센터   0.012792
# 15             회산교   1.100006
# 16              회동  -0.278119
# 17       환경시설관리사업소  -0.307739
# 18             화천리  -0.449156
# 19            화천기전   1.786192
# 20           화인아파트   0.281669
# 21              화목  -3.115367
# 22            호산마을  -0.276712
# 23       호산나노인복지센터  -0.639075
# 24           호계중학교  -0.152020
# 25            호계농협   0.926213
# 26              호계   0.016083
# 27           혜창아파트  -0.240169
# 28         혜성아파트입구  -0.080184
# 29          형제상가빌라  -0.114067
# ...

# %%
df4 = df4[['버스번호','station_list']]

# %%
df4
# Out:
#      버스번호                                       station_list   total_sum
# 0       1  [판신마을, 판신, 태광주유소, 칠성아파트, 참사랑병원 앞, 주남저수지, 주남, 제...  -33.815258
# 1       2  [판신마을, 판신, 태광주유소, 칠성아파트, 참사랑병원 앞, 주남저수지, 주남, 제...  -18.757814
# 2       3     [제동마을, 유청, 윗대방, 세진테크원, 덕현마을, 대산일반산업단지, 대방, 가술]   -2.091111
# 3       7  [태광주유소, 참사랑병원 앞, 의창동환승센터, 윤병원, 용정, 용잠삼거리, 용암, ...   -4.534392
# 4       8  [협성아파트, 한보아파트, 창원역, 유성아파트, 소계입구, 소계갓등1길, 구암중학교...    6.679715
# 5      10  [흥한웰가아파트, 화천리, 행복한병원, 한림아파트, 피오르빌아파트, 파티마병원, 트...   70.345290
# 6      11  [흥한웰가아파트, 화천리, 현도, 행복한병원, 행복이가득한집, 한림아파트, 피오르빌...   41.463216
# 7      12  [힐스테이트1차, 흥한웰가아파트, 휴먼빌2단지, 휴먼빌3차아파트, 휴먼빌1단지, 한...   70.011376
# 8      13  [흥한웰가아파트, 화천리, 현천, 행복한병원, 한수, 한림아파트, 피오르빌아파트, ...   56.954703
# 9      14  [흥한웰가아파트, 화천리, 행복한병원, 행복이가득한집, 한림아파트, 피오르빌아파트,...   47.602335
# 10     15  [흥한웰가아파트, 화천리, 현천, 현도, 행복한병원, 행복이가득한집, 팔룡동주민센터...  -42.178776
# 11     17  [힐스테이트4차, 힐스테이트3차, 힐스테이트1차, 흥한웰가아파트, 휴먼빌2단지, 휴...   63.381549
# ...

# %%
sum_li =[]
for i in range(0,len(df4)):
    sum = 0
    for j in range(0,len(df5)):
        if df5['station'][j] in df4['station_list'][i]:
            sum = sum + df5['total_num'][j]
    sum_li.append(sum)
sum_li
# Out:
# [-33.815257719816685,
#  -18.757813582766012,
#  -2.0911109694970413,
#  -4.534391980569516,
#  6.679715450764184,
#  70.34529012216419,
#  41.46321641009024,
#  70.01137591781215,
#  56.95470337294015,
#  47.60233459168382,
#  -42.17877633153919,
#  63.38154901783109,
#  -0.2980034896947778,
#  64.40966436923125,
#  35.85185585695899,
#  12.83598387341507,
#  59.69611033312026,
#  54.25098607722489,
#  37.066023672605986,
#  4.610711167146562,
#  -12.227381688313839,
#  -16.783879155724698,
#  -3.4526567952469924,
#  -102.02397145251325,
#  75.30649466759519,
#  75.30649466759519,
#  -99.89166055980266,
#  -12.712735298003501,
#  -13.508882907893547,
#  -17.885533966389044,
#  45.66121559356117,
#  72.53084528516305,
#  71.6033140408984,
#  54.15096016616499,
#  -53.590276817801445,
#  79.94898606350621,
#  64.7357853763115,
#  67.15479852691523,
#  54.294908156744185,
#  41.18228346316993,
#  60.01163799749954,
#  46.44623893673897,
#  42.159689751845235,
#  42.43297522584836,
# ...

# %%
df4['total_sum'] = sum_li

# %%
df6 =df4[['버스번호','total_sum']]

# %%
df6.to_excel('노선별점수.xlsx')

# %%
for i in range(0,len(total)):
    if(total['grade'][i]<200):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = '	#ff0000',radius=1 ).add_to(map)
