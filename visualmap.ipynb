# %%
import pandas as pd
import matplotlib.pyplot as plt


loc_pm = pd.read_excel("위도경도PM.xlsx")

# %%
loc_pm
# Out:
#      station_no         lon        lat       pm10      pm2.5        CO  \
# 0             1  128.685505  35.157249  42.239244  21.719005  0.460562
# 1             2  128.688688  35.157249  42.457453  21.817222  0.462330
# 2             3  128.682322  35.159517  42.212003  21.680870  0.462448
# 3             4  128.685505  35.159517  42.590194  21.848494  0.465180
# 4             5  128.688688  35.159517  42.528927  21.788734  0.461975
# 5             6  128.679139  35.161784  42.184762  21.642734  0.464334
# 6             7  128.682322  35.161784  42.553926  21.807951  0.467147
# 7             8  128.685505  35.161784  43.189011  22.044079  0.467579
# 8             9  128.688688  35.161784  42.600400  21.760246  0.461619
# 9            10  128.675956  35.164051  42.157521  21.604599  0.466220
# 10           11  128.679139  35.164051  42.517658  21.767409  0.469114
# 11           12  128.682322  35.164051  43.152743  22.003537  0.469546
# ...

# %%
import matplotlib.image as mpimg
import seaborn as sns
img = mpimg.imread("창원시.png")
ax = loc_pm.plot(kind="scatter", x="lon", y="lat",figsize=(10,7),c="pm",cmap=plt.cm.Reds,alpha=0.8)
plt.imshow(img,extent=[128.55, 128.74, 35.14, 35.26])

# %%
import pandas as pd
station = pd.read_excel("보간법적용.xlsx")

# %%
import pandas as pd
import matplotlib.pyplot as plt

bx = station.plot(kind="scatter",x="lon",y="lat",figsize=(10,7),alpha=0.7,c="pm",cmap=plt.cm.Reds)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lon'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-fc6af6acccc2> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ...

# %%
import folium
import pandas as pd
total = pd.read_excel('정류장점수.xlsx')
map = folium.Map(location=[35.220735, 128.650511],zoom_start=11)
for i in range(0,len(total)):
    if(total['grade'][i]<200):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = '	#ff0000',radius=1 ).add_to(map)
    elif(total['grade'][i]<400):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = '#fe5b05',radius=1 ).add_to(map)
    elif(total['grade'][i]<600):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = '#ffc701',radius=1 ).add_to(map)
    elif(total['grade'][i]<800):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = '#1dd400',radius=1 ).add_to(map)

display(map)
map.save('station_score.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium
import pandas as pd
total = pd.read_excel('정류장점수.xlsx')
map = folium.Map(location=[35.220735, 128.650511],zoom_start=11)
for i in range(0,len(total)):
    if(total['grade'][i]<200):
        folium.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = 'w',fill_color='purple',radius=10).add_to(map)
    elif(total['grade'][i]<400):
        folium.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = 'w',fill_color='navy',radius=6 ).add_to(map)
    elif(total['grade'][i]<600):
        folium.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = 'w',fill_color='blue',radius=3 ).add_to(map)
    elif(total['grade'][i]<800):
        folium.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        clustered_marker = False, color = 'w',fill_color='cyan',radius=1 ).add_to(map)

for i in range(0,len(total)):
    if(total['station'][i] in li1):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#ff0000',radius=2 ).add_to(map)
    elif(total['station'][i] in li2):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#ff7e02',radius=2 ).add_to(map)
    elif(total['station'][i] in li3):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#ffd700',radius=2 ).add_to(map)
    elif(total['station'][i] in li4):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#1dd400',radius=2 ).add_to(map)
    elif(total['station'][i] in li5):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#001eff',radius=2 ).add_to(map)
    elif(total['station'][i] in li6):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#000442',radius=2 ).add_to(map)
    elif(total['station'][i] in li7):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#570076',radius=2 ).add_to(map)
    elif(total['station'][i] in li8):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#1b1b1b',radius=2 ).add_to(map)
    elif(total['station'][i] in li9):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#f5a2d5',radius=2 ).add_to(map)
    elif(total['station'][i] in li10):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#4bff36',radius=2 ).add_to(map)
        
display(map)
map.save('station_score.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
final = pd.read_excel('노선별점수.xlsx')

# %%
final = final[['버스번호','station_list','total_sum']]

# %%
final2=final.sort_values(["total_sum"],ascending=[False]).head(10)

# %%
final2=final2[['버스번호','station_list','total_sum']]

# %%
final2
# Out:
#     버스번호                                       station_list   total_sum
# 74   109  ['해운초등학교', '합포동', '합성동', '도계동', '한일타운', '한일로타리...  161.439474
# 68   102  ['향교입구', '해운초등학교', '합포동', '합성동', '한화테크윈 제2사업장'...  161.237803
# 69   103  ['회산교', '해운초등학교', '합포주유소', '합성동', '한림아파트', '한국...  147.272809
# 73   108  ['해운초등학교', '합포동', '합성동', '한일타운', '한일로타리', '한국폴...  138.600030
# 79   115  ['호계농협', '현대아파트', '현대아파트', '합성동', '한효국화맨션', '한...  136.829480
# 76   111  ['합성동', '한효국화맨션', '한주아파트입구', '한국전력', '팔룡중학교', ...  125.745787
# 72   107  ['효성중공업', '해운초등학교', '합포동', '한화테크윈 제2사업장', '한림아...  125.274712
# 160  703  ['합성동', '한일타운', '한림아파트', '한국전력', '트리비앙아파트', '토...  117.635501
# 78   113  ['호계농협', '현대아파트', '현대아파트', '합성동', '도계동', '한효국화...  113.676177
# 80   116  ['한효국화맨션', '한주아파트입구', '한림아파트', '한국철강', '트리비앙아파...  110.403380

# %%
li1=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[74].split(',')

# %%
li2=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[68].split(',')
li3=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[69].split(',')
li4=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[73].split(',')
li5=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[79].split(',')
li6=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[76].split(',')
li7=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[72].split(',')
li8=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[160].split(',')
li9=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[78].split(',')
li10=final2['station_list'].str.replace('[','').str.replace(']','').str.replace('\'','').str.replace(' ','')[80].split(',')

# %%
map = folium.Map(location=[35.220735, 128.650511],zoom_start=12)
for i in range(0,len(total)):
    if(total['station'][i] in li1):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#ff0000',radius=2 ).add_to(map)
    elif(total['station'][i] in li2):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#ff7e02',radius=2 ).add_to(map)
    elif(total['station'][i] in li3):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#ffd700',radius=2 ).add_to(map)
    elif(total['station'][i] in li4):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#1dd400',radius=2 ).add_to(map)
    elif(total['station'][i] in li5):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#001eff',radius=2 ).add_to(map)
    elif(total['station'][i] in li6):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#000442',radius=2 ).add_to(map)
    elif(total['station'][i] in li7):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#570076',radius=2 ).add_to(map)
    elif(total['station'][i] in li8):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#1b1b1b',radius=2 ).add_to(map)
    elif(total['station'][i] in li9):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#f5a2d5',radius=2 ).add_to(map)
    elif(total['station'][i] in li10):
        folium.vector_layers.CircleMarker(
        location = [total['lat_x'][i],total['lon_x'][i]],
        color = '#4bff36',radius=2 ).add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
.replace(' ','')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-ac665ae42bd3> in <module>
# ----> 1 li1.str.replace(' ','')
#
# AttributeError: 'list' object has no attribute 'str'

# %%
total
# Out:
#       Unnamed: 0  ...1    no      id     station   Mon   Tue   Wed    Thu  \
# 0            115   114   115  114221     트리비앙아파트  1389  1436  1432   1368
# 1            945   944   955  201215        남창원역   394   447   420    405
# 2             85    84    85  218803    한국폴리텍7대학   535   592   529    587
# 3            154   153   155  214202     창원종합운동장   486   459   528    456
# 4            566   565   574  201213        세아제강   110   118   112    126
# 5            769   768   779  214204       만남의광장     0     2     3      0
# 6            323   322   329  114227       은아아파트  7510  7964  8010   8850
# 7            786   785   796  400116   마산시외버스터미널  9941  9689  9816  10073
# 8            984   983   994  212205        국민은행   248   282   296    279
# 9            224   223   226  114223      중앙고등학교  1054  1030  1038    997
# 10           164   163   165  213301        창원병원   858   913   925    877
# 11           562   561   570  212205        국민은행    32    39    33     41
# ...

# %%
geo_str

# %%
import json
geo_path = 'TL_SCCO_EMD_WGS84.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-147560b301dc> in <module>
#       1 import json
#       2 geo_path = 'TL_SCCO_EMD_WGS84.json'
# ----> 3 geo_str = json.load(open(geo_path, encoding='utf-8'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'TL_SCCO_EMD_WGS84.json'

# %%
import folium
geo_path = '지도json/skorea-submunicipalities-2018-geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
m = folium.Map(location = [35.220735, 128.650511] , tiles= "Stamen Terrain", zoom_start=12)
folium.Choropleth(geo_data=geo_str,fill_color='white').add_to(m)
for i in range(0,len(df1)):
    folium.vector_layers.CircleMarker(
        location = [df1['경도'][i],df1['위도'][i]],
        clustered_marker = False, color = '#ff0000',radius=1).add_to(m)
m.save('folium_kr.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8017b6b8210> in <module>
#       1 import folium
#       2 geo_path = '지도json/skorea-submunicipalities-2018-geo.json'
# ----> 3 geo_str = json.load(open(geo_path, encoding='utf-8'))
#       4 m = folium.Map(location = [35.220735, 128.650511] , tiles= "Stamen Terrain", zoom_start=12)
#       5 folium.Choropleth(geo_data=geo_str,fill_color='white').add_to(m)
#
# NameError: name 'json' is not defined

# %%
import pandas as pd
df1 = pd.read_excel('측정소위도경도.xlsx')

# %%
help(folium.Choropleth)
# Out:
# Help on class Choropleth in module folium.features:
#
# class Choropleth(folium.map.FeatureGroup)
#  |  Choropleth(geo_data, data=None, columns=None, key_on=None, bins=6, fill_color='blue', nan_fill_color='black', fill_opacity=0.6, nan_fill_opacity=None, line_color='black', line_weight=1, line_opacity=1, name=None, legend_name='', overlay=True, control=True, show=True, topojson=None, smooth_factor=None, highlight=None, **kwargs)
#  |
#  |  Apply a GeoJSON overlay to the map.
#  |
#  |  Plot a GeoJSON overlay on the base map. There is no requirement
#  |  to bind data (passing just a GeoJSON plots a single-color overlay),
#  |  but there is a data binding option to map your columnar data to
#  |  different feature objects with a color scale.
#  |
#  |  If data is passed as a Pandas DataFrame, the "columns" and "key-on"
#  |  keywords must be included, the first to indicate which DataFrame
#  |  columns to use, the second to indicate the layer in the GeoJSON
# ...

# %%
import folium
m2 = folium.Map(location = [35.220735, 128.650511] , tiles= "OpenStreetMap", zoom_start=12)

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.GeoJson(geo_str,name='json_data').add_to(m)
m

# %%
import folium
m2 = folium.Map(location = [35.220735, 128.650511] , tiles= "OpenStreetMap", zoom_start=11.5)

for i in range(0,len(df1)):
    folium.Marker(
        location = [df1['경도'][i],df1['위도'][i]],
       icon=folium.Icon(color='red')).add_to(m2)
m2.save('folium_kr.html')

# %%
m2.save('folium_kr.html')

# %%
df1['위도'][0]
# Out:
# 128.689528
