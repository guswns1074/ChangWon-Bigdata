# %%
from sklearn import datasets
import pandas as pd


total = pd.read_excel('보간법적용.xlsx')
total
# Out:
#       Unnamed: 0    no      id       station   Mon   Tue   Wed   Thu   Fri  \
# 0              0     1  103118       힐스테이트4차   360   426   397   391   445
# 1              1     2  103115       힐스테이트3차    45    42    63    66    32
# 2             20     3  103103       힐스테이트1차   282   326   301   329   308
# 3             44     4  119303       흥한웰가아파트  1735  1882  1674  1644  1727
# 4             75     5  103602     휴먼시아2단지입구    95   103    91    92    92
# 5             76     6  103601       휴먼시아2단지    71    87    87   102    89
# 6             77     7  109501       휴먼시아1단지   164   144   141   152   140
# 7              2     8  104713        휴먼빌2단지   266   267   262   274   294
# 8              3     9  104721      휴먼빌3차아파트    36    30    42    35    40
# 9              4    10  104714        휴먼빌1단지    25    30    32    19    31
# 10           107    11  201211         효성중공업    37    38    37    35    33
# ...

# %%
total2 = total[['no','Week','count','pm10']]

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster
import matplotlib.pyplot as plt

total3 = linkage(total2,method='complete')

total4 = fcluster(total2,3,criterion='distance')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-22f33e9b045b> in <module>
#       5 total3 = linkage(total2,method='complete')
#       6
# ----> 7 total4 = fcluster(total2,3,criterion='distance')
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in fcluster(Z, t, criterion, depth, R, monocrit)
#    2615     """
#    2616     Z = np.asarray(Z, order='c')
# -> 2617     is_valid_linkage(Z, throw=True, name='Z')
#    2618
#    2619     n = Z.shape[0] + 1
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in is_valid_linkage(Z, warning, throw, name)
#    2325         if _check_hierarchy_uses_cluster_before_formed(Z):
#    2326             raise ValueError('Linkage %suses non-singleton cluster before '
# -> 2327                              'it is formed.' % name_str)
#    2328         if _check_hierarchy_uses_cluster_more_than_once(Z):
# ...

# %%
total2 = total[['count','pm10']]

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# 인위적으로 2차원 데이터를 생성합니다
total = pd.read_excel('보간법적용.xlsx')
total2 = total[['count','pm10']]
X = total2

# 군집 모델을 만듭니다
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)


total2['label'] = kmeans.predict(X)
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from sklearn.datasets import load_iris
import pandas as pd
#
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster

iris = load_iris()

df = pd.DataFrame(iris.data, columns=['Sepal length','Sepal width','Petal length','Petal width'])
df['labels'] = iris.target

# %%
from sklearn.datasets import load_iris
import pandas as pd
#
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.cluster.hierarchy import fcluster
total = pd.read_excel('보간법적용.xlsx')
total2 = total[['count','pm10']]

mergings = linkage(total2,method='complete')

import matplotlib.pyplot as plt
plt.figure(figsize=(40,20))
dendrogram(mergings,
           labels = df.as_matrix(columns=['labels']),
           leaf_rotation=90,
           leaf_font_size=20
)
plt.show()
# Out:
# C:\Users\CPB06GameN\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-27ecae53779c> in <module>
#      14            labels = df.as_matrix(columns=['labels']),
#      15            leaf_rotation=90,
# ---> 16            leaf_font_size=20
#      17 )
#      18 plt.show()
#
# ~\Anaconda3\lib\site-packages\scipy\cluster\hierarchy.py in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    3393         contraction_marks=contraction_marks,
#    3394         link_color_func=link_color_func,
# ...

# %%
len(mergings)
# Out:
# 1096

# %%
len(total2)
# Out:
# 1097
